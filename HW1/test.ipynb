# %% [markdown]
# <a href="https://colab.research.google.com/github/Penguinboy1990/Machine-Learning/blob/main/HW1/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **My First Notebook**
#
# * This demonstrates a simple notebook
# * etc.
# ![image.png](data:image/png;base64,...)

# %%
!1s
# Out:
# /bin/bash: line 1: 1s: command not found

# %%
# !pwd
# Out:
# /content

# %%
x = 320
print(x)
# Out:
# 320
